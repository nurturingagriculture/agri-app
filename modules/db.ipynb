# %%
GROQ_API = r"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"
GOOGLE_API = r"AIzaSyCcP6OitLO4j8DpTeyelRoNNiHSj_CXXto"
HF_API = r"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"

# %%
import os
import faiss
from langchain.vectorstores import FAISS
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.embeddings import HuggingFaceInferenceAPIEmbeddings
from dotenv import load_dotenv

# Load environment variables
load_dotenv()
os.environ["HF_TOKEN"] = os.getenv("HF_TOKEN")

# Initialize Embeddings
embeddings = HuggingFaceInferenceAPIEmbeddings(
    api_key=os.environ["HF_TOKEN"],
    model_name="sentence-transformers/all-MiniLM-l6-v2",
)

# Sample text data to be embedded
TEXT_DATA = [
    "Agriculture is the backbone of many economies.",
    "Soil health is crucial for sustainable farming.",
    "Climate change affects crop yield and quality.",
    "Organic farming is gaining popularity worldwide.",
]

# Split text into smaller chunks
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=100, chunk_overlap=20
)
texts = text_splitter.create_documents(TEXT_DATA)

# Create FAISS vector store
vectorstore = FAISS.from_documents(texts, embeddings)

# Define storage path
FAISS_PATH = r"C:\Users\tejas\OneDrive\Desktop\T_work\Freelancing\agricultural-app\modules\faiss_index_"

# Save FAISS index
vectorstore.save_local(FAISS_PATH)

print("FAISS vector database created and stored successfully.")
# Out:
# FAISS vector database created and stored successfully.

# %%
import os
import faiss
from langchain.vectorstores import FAISS
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.embeddings import HuggingFaceInferenceAPIEmbeddings
from dotenv import load_dotenv
from PyPDF2 import PdfReader

# Load environment variables
load_dotenv()
os.environ["HF_TOKEN"] = os.getenv("HF_TOKEN")

# Initialize Embeddings
embeddings = HuggingFaceInferenceAPIEmbeddings(
    api_key=os.environ["HF_TOKEN"],
    model_name="sentence-transformers/all-MiniLM-l6-v2",
)

# Function to process PDFs in a folder
def process_pdfs(folder_path):
    text_data = []
    for file in os.listdir(folder_path):
        if file.endswith(".pdf"):
            reader = PdfReader(os.path.join(folder_path, file))
            text = "\n".join([page.extract_text() for page in reader.pages if page.extract_text()])
            text_data.append(text)
    return text_data

# Function to process .txt files in a folder
def process_txts(folder_path):
    text_data = []
    for file in os.listdir(folder_path):
        if file.endswith(".txt"):
            with open(os.path.join(folder_path, file), "r", encoding="utf-8") as f:
                text_data.append(f.read())
    return text_data

# Define folder path for PDFs and TXT files
FOLDER_PATH = "path/to/your/folder"

# Process text data from PDFs and TXT files
TEXT_DATA = process_pdfs(FOLDER_PATH) + process_txts(FOLDER_PATH)

# Split text into smaller chunks
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000, chunk_overlap=200
)
texts = text_splitter.create_documents(TEXT_DATA)

# Create FAISS vector store
vectorstore = FAISS.from_documents(texts, embeddings)

# Define storage path
FAISS_PATH = r"C:\Users\tejas\OneDrive\Desktop\T_work\Freelancing\agricultural-app\modules\faiss_index_"

# Save FAISS index
vectorstore.save_local(FAISS_PATH)

print("FAISS vector database created and stored successfully.")
